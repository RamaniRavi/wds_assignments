# %%
import numpy as np
num = np.array([1.5, 2.8, 0.2, 3.1])

# %%
num[1]
# Out:
# np.float64(2.8)

# %%
num[1:3]
# Out:
# array([2.8, 0.2])

# %%
num[0] = 3.5

# %%
num
# Out:
# array([3.5, 2.8, 0.2, 3.1])

# %%
for n in num:
    if n>2:
     print(n)
# Out:
# 3.5
# 2.8
# 3.1

# %%
[n for n in num if n>2]
# Out:
# [np.float64(3.5), np.float64(2.8), np.float64(3.1)]

# %%
[n if n > 2 else 0 for n in num]
# Out:
# [np.float64(3.5), np.float64(2.8), 0, np.float64(3.1)]

# %%
num
# Out:
# array([3.5, 2.8, 0.2, 3.1])

# %%
x = pow(num,2)
x
# Out:
# array([12.25,  7.84,  0.04,  9.61])

# %%
x = [n+5.2 for n in x]
x
# Out:
# [np.float64(17.45),
#  np.float64(13.04),
#  np.float64(5.24),
#  np.float64(14.810000000000002)]

# %%
import numpy as np
np.mean(x)
# Out:
# np.float64(12.635)

# %%
len(x)
# Out:
# 4

# %%
result = [-5, 7, 8, "Error", 5]
result
# Out:
# [-5, 7, 8, 'Error', 5]

# %%
result[3]
# Out:
# 'Error'

# %%
[type(n) for n in result]
# Out:
# [int, int, int, str, int]

# %%
result.append(3)
result.append(5)
result
# Out:
# [-5, 7, 8, 'Error', 5, 3, 5]

# %%
result[3] = 0
result
# Out:
# [-5, 7, 8, 0, 5, 3, 5]

# %%
dicti = {}
dicti
# Out:
# {}

# %%
dicti = {'USA': 112, 'Germany': 36, 'China': 100}
dicti
# Out:
# {'USA': 112, 'Germany': 36, 'China': 100}

# %%
dicti['Italy'] = 40
dicti
# Out:
# {'USA': 112, 'Germany': 36, 'China': 100, 'Italy': 40}

# %%
del dicti['Germany']
dicti
# Out:
# {'USA': 112, 'China': 100, 'Italy': 40}

# %%
dicti['USA'] = 113
dicti
# Out:
# {'USA': 113, 'China': 100, 'Italy': 40}

# %%
for key,value in dicti.items():
    print(f'Key: {key}, Value: {value}')
# Out:
# Key: USA, Value: 113
# Key: China, Value: 100
# Key: Italy, Value: 40

# %%
matrix = [[2,4,3], [1,5,7]]
matrix
# Out:
# [[2, 4, 3], [1, 5, 7]]

# %%
for row in matrix:
    print(*row)
# Out:
# 2 4 3
# 1 5 7

# %%
matrix[1][1] = 0
matrix
# Out:
# [[2, 4, 3], [1, 0, 7]]

# %%
row_sum = 0
for i in matrix[0]:
    row_sum = row_sum+i
row_sum
# Out:
# 9

# %%
sum(matrix[0])
# Out:
# 9

# %%
column_sum = 0
for i in matrix:
    column_sum += i[0]
column_sum
# Out:
# 3

# %%
print( matrix[0][0] + matrix[1][0])
# Out:
# 3
